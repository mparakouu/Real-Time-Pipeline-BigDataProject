# %%
import pymongo

# %%
client = pymongo.MongoClient("mongodb://localhost:27017/")
TheDatabase = client["MyVehiclesData"]
TheCollection = TheDatabase["RawVehiclesData"]

# %%
for document in TheCollection.find():
    print(document)
# Out:
# {'_id': ObjectId('663b491a65c3f13810a4c7a5'), 'link': 'N1I1', 'time': '2024-05-07 18:40:15', 'speed': 0.0}
# {'_id': ObjectId('663b491a65c3f13810a4c7a6'), 'link': 'N1I1', 'time': '2024-05-07 18:40:20', 'speed': 0.0}
# {'_id': ObjectId('663b491a65c3f13810a4c7a7'), 'link': 'N1I1', 'time': '2024-05-07 18:40:25', 'speed': 0.0}
# {'_id': ObjectId('663b491a65c3f13810a4c7a8'), 'link': 'N1I1', 'time': '2024-05-07 18:40:30', 'speed': 0.0}
# {'_id': ObjectId('663b491a65c3f13810a4c7a9'), 'link': 'I1S1', 'time': '2024-05-07 18:40:35', 'speed': 0.0}
# {'_id': ObjectId('663b491a65c3f13810a4c7aa'), 'link': 'I1S1', 'time': '2024-05-07 18:40:40', 'speed': 30.0}
# {'_id': ObjectId('663b491a65c3f13810a4c7ab'), 'link': 'I1S1', 'time': '2024-05-07 18:40:45', 'speed': 30.0}
# {'_id': ObjectId('663b491a65c3f13810a4c7ac'), 'link': 'I1S1', 'time': '2024-05-07 18:40:45', 'speed': 30.0}
# {'_id': ObjectId('663b491a65c3f13810a4c7ad'), 'link': 'trip_end', 'time': '2024-05-07 18:40:45', 'speed': -1.0}
# ...
