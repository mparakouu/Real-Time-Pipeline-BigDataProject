# %%
import pymongo
import pandas as pd
import json

# %%
client = pymongo.MongoClient("mongodb://localhost:27017")

# %%
TheDataframe = pd.read_csv("vehicles_data.csv")

# %%
TheDataframe.head(10)
# Out:
#    name  dn orig dest   t                    link      x      s     v
# 0     0   5   N1   S1  15                    N1I1    0.0  125.0  30.0
# 1     0   5   N1   S1  20                    N1I1  100.0  175.0  20.0
# 2     0   5   N1   S1  25                    N1I1  250.0  175.0  30.0
# 3     0   5   N1   S1  30                    N1I1  400.0   -1.0  30.0
# 4     0   5   N1   S1  35                    I1S1   50.0   -1.0  20.0
# 5     0   5   N1   S1  40                    I1S1  200.0   -1.0  30.0
# 6     0   5   N1   S1  45                    I1S1  350.0   -1.0  30.0
# 7     0   5   N1   S1  45                trip_end   -1.0   -1.0  -1.0
# 8     1   5   N1   S1  25  waiting_at_origin_node   -1.0   -1.0  -1.0
# 9     1   5   N1   S1  30  waiting_at_origin_node   -1.0   -1.0  -1.0

# %%
TheDataframe.shape
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'MyVehiclesData'), 'shape')

# %%
TheData = TheDataframe.head(10).to_dict(orient="records")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 TheData = TheDataframe.head(10).to_dict(orient="records")
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pymongo/collection.py:3473, in Collection.__call__(self, *args, **kwargs)
#    3471 """This is only here so that some API misusages are easier to debug."""
#    3472 if "." not in self.__name:
# -> 3473     raise TypeError(
#    3474         "'Collection' object is not callable. If you "
#    3475         "meant to call the '%s' method on a 'Database' "
#    3476         "object it is failing because no such method "
#    3477         "exists." % self.__name
#    3478     )
#    3479 raise TypeError(
#    3480     "'Collection' object is not callable. If you meant to "
#    3481     "call the '%s' method on a 'Collection' object it is "
# ...

# %%
TheData
# Out:
# [{'name': 0,
#   'dn': 5,
#   'orig': 'N1',
#   'dest': 'S1',
#   't': 15,
#   'link': 'N1I1',
#   'x': 0.0,
#   's': 125.0,
#   'v': 30.0,
#   '_id': ObjectId('663a4a0adca3b8bf88281df1')},
#  {'name': 0,
#   'dn': 5,
#   'orig': 'N1',
#   'dest': 'S1',
#   't': 20,
#   'link': 'N1I1',
#   'x': 100.0,
#   's': 175.0,
#   'v': 20.0,
#   '_id': ObjectId('663a4a0adca3b8bf88281df2')},
#  {'name': 0,
#   'dn': 5,
#   'orig': 'N1',
#   'dest': 'S1',
#   't': 25,
#   'link': 'N1I1',
#   'x': 250.0,
#   's': 175.0,
#   'v': 30.0,
#   '_id': ObjectId('663a4a0adca3b8bf88281df3')},
#  {'name': 0,
#   'dn': 5,
#   'orig': 'N1',
#   'dest': 'S1',
#   't': 30,
#   'link': 'N1I1',
#   'x': 400.0,
#   's': -1.0,
#   'v': 30.0,
#   '_id': ObjectId('663a4a0adca3b8bf88281df4')},
#  {'name': 0,
#   'dn': 5,
#   'orig': 'N1',
#   'dest': 'S1',
#   't': 35,
#   'link': 'I1S1',
#   'x': 50.0,
#   's': -1.0,
#   'v': 20.0,
#   '_id': ObjectId('663a4a0adca3b8bf88281df5')},
#  {'name': 0,
#   'dn': 5,
# ...

# %%
database = client["MyVehiclesData"]

# %%
print(database)
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'MyVehiclesData')

# %%
database.vehiclesData.insert_many(TheData)
